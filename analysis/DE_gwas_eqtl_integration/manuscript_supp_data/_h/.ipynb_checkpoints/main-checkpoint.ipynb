# %% [markdown]
# # Generate supplemental data of all significant integration analysis

# %%
import pandas as pd

# %%
genes = pd.read_csv('../../_m/genes/integration_by_symbol.txt', sep='\t').rename(columns={'gene': 'Feature_ID'})
genes['Feature_Type'] = 'Gene'
genes.head()
# Out:
#            Feature_ID Symbol                  SNP_eqtl A1 A2 risk_allele  \
# 0  ENSG00000143420.17   ENSA  rs12124898:150154352:C:T  C  T           T
# 1  ENSG00000066248.14   NGEF    rs778353:233788350:C:T  C  T           T
# 2  ENSG00000066248.14   NGEF   rs1083521:233788734:A:G  A  G           G
# 3  ENSG00000066248.14   NGEF   rs1083520:233788862:A:G  A  G           G
# 4  ENSG00000066248.14   NGEF   rs1083519:233788869:C:T  C  T           T
#
#         OR             P       FDR  adj.P.Val     logFC         t    eqtl_t  \
# 0  0.92697  1.430000e-08  0.003994   0.017038  0.045351  3.249546 -3.926103
# 1  0.93531  2.680000e-12  0.000037   0.015120  0.109010  3.294629 -5.096546
# 2  0.93639  6.320000e-12  0.000036   0.015120  0.109010  3.294629 -5.100574
# 3  0.93574  4.980000e-12  0.000036   0.015120  0.109010  3.294629 -5.100574
# 4  0.93615  5.210000e-12  0.000036   0.015120  0.109010  3.294629 -5.100574
#
#   de_dir eqtl_gwas_dir agree_direction Feature_Type
# 0     Up          Down              No         Gene
# 1     Up          Down              No         Gene
# 2     Up          Down              No         Gene
# 3     Up          Down              No         Gene
# 4     Up          Down              No         Gene

# %%
trans = pd.read_csv('../../_m/transcripts/integration_by_symbol.txt', sep='\t').rename(columns={'gene': 'Feature_ID', 'gene_name': 'Symbol'})
trans['Feature_Type'] = 'Transcript'
trans.head()
# Out:
#           Feature_ID   Symbol                SNP_eqtl A1 A2 risk_allele  \
# 0  ENST00000617168.4  ZSCAN26   rs414205:28526419:G:C  G  C           G
# 1  ENST00000617168.4  ZSCAN26   rs436827:28557133:T:A  T  A           T
# 2  ENST00000617168.4  ZSCAN26  rs7741058:28596420:T:A  T  A           A
# 3  ENST00000617168.4  ZSCAN26  rs9378185:28606662:G:A  G  A           A
# 4  ENST00000617168.4  ZSCAN26  rs1810619:28609097:G:T  G  T           T
#
#         OR             P       FDR  adj.P.Val     logFC         t    eqtl_t  \
# 0  1.07930  1.070000e-14  0.002266   0.030366 -0.396302 -3.560797 -4.272345
# 1  1.08020  7.450000e-15  0.001155   0.030366 -0.396302 -3.560797 -4.448464
# 2  0.90788  9.130000e-18  0.004158   0.030366 -0.396302 -3.560797 -4.106542
# 3  0.92754  7.160000e-14  0.002219   0.030366 -0.396302 -3.560797 -4.277918
# 4  0.92814  2.060000e-13  0.002541   0.030366 -0.396302 -3.560797 -4.241781
#
#   de_dir eqtl_gwas_dir agree_direction Feature_Type
# 0   Down          Down             Yes   Transcript
# 1   Down          Down             Yes   Transcript
# 2   Down          Down             Yes   Transcript
# 3   Down          Down             Yes   Transcript
# 4   Down          Down             Yes   Transcript

# %%
exons = pd.read_csv('../../_m/exons/integration_by_symbol.txt', sep='\t').rename(columns={'gene': 'Feature_ID'})
exons['Feature_Type'] = 'Exon'
exons.head()
# Out:
#   Feature_ID Symbol                 SNP_eqtl A1 A2 risk_allele       OR  \
# 0    e127798   VRK2   rs2717068:58094873:A:C  A  C           C  0.94673
# 1    e127798   VRK2  rs59159185:58102107:T:A  T  A           A  0.91021
# 2    e127798   VRK2                rs2683634  T  C           C  0.94392
# 3    e127798   VRK2   rs1356545:58123798:T:C  T  C           C  0.94384
# 4    e127798   VRK2   rs2717056:58128804:C:T  C  T           T  0.94400
#
#               P       FDR  adj.P.Val     logFC         t    eqtl_t de_dir  \
# 0  2.360000e-08  0.005217   0.034502 -0.145416 -3.136916  4.067721   Down
# 1  1.370000e-08  0.007748   0.034502 -0.145416 -3.136916  3.952051   Down
# 2  2.990000e-09  0.009648   0.034502 -0.145416 -3.136916  3.885998   Down
# 3  2.850000e-09  0.002981   0.034502 -0.145416 -3.136916  4.225101   Down
# 4  3.170000e-09  0.009144   0.034502 -0.145416 -3.136916  3.902287   Down
#
#   eqtl_gwas_dir agree_direction Feature_Type
# 0            Up              No         Exon
# 1            Up              No         Exon
# 2            Up              No         Exon
# 3            Up              No         Exon
# 4            Up              No         Exon

# %%
juncs = pd.read_csv('../../_m/junctions/integration_by_symbol.txt', sep='\t').rename(columns={'gene': 'Feature_ID'})
juncs['Feature_Type'] = 'Junction'
juncs.head()
# Out:
#                 Feature_ID Symbol                 SNP_eqtl A1  A2 risk_allele  \
# 0  chr1:8359987-8360111(-)   RERE      rs13596:8421203:T:C  T   C           T
# 1  chr1:8359987-8360111(-)   RERE                rs2252865  T   C           T
# 2  chr1:8359987-8360111(-)   RERE               rs10779702  A   G           A
# 3  chr1:8359987-8360111(-)   RERE                 rs894875  C   T           C
# 4  chr1:8359987-8360111(-)   RERE  rs36085291:8435172:T:TC  T  TC           T
#
#         OR             P       FDR  adj.P.Val     logFC         t    eqtl_t  \
# 0  1.05960  1.320000e-08  0.005969   0.009726 -0.227594 -3.772118  4.069341
# 1  1.05890  1.480000e-08  0.006096   0.009726 -0.227594 -3.772118  4.063307
# 2  1.05960  1.030000e-08  0.005074   0.009726 -0.227594 -3.772118  4.115450
# 3  1.05790  3.200000e-08  0.003680   0.009726 -0.227594 -3.772118  4.204747
# 4  1.05844  2.514000e-08  0.003680   0.009726 -0.227594 -3.772118  4.204747
#
#   de_dir eqtl_gwas_dir agree_direction Feature_Type
# 0   Down            Up              No     Junction
# 1   Down            Up              No     Junction
# 2   Down            Up              No     Junction
# 3   Down            Up              No     Junction
# 4   Down            Up              No     Junction

# %%
df = pd.concat([genes, trans, exons, juncs], axis=0, sort=False)
print(df.shape)
df.head(2)
# Out:
# (24722, 17)
#            Feature_ID Symbol                  SNP_eqtl A1 A2 risk_allele  \
# 0  ENSG00000143420.17   ENSA  rs12124898:150154352:C:T  C  T           T
# 1  ENSG00000066248.14   NGEF    rs778353:233788350:C:T  C  T           T
#
#         OR             P       FDR  adj.P.Val     logFC         t    eqtl_t  \
# 0  0.92697  1.430000e-08  0.003994   0.017038  0.045351  3.249546 -3.926103
# 1  0.93531  2.680000e-12  0.000037   0.015120  0.109010  3.294629 -5.096546
#
#   de_dir eqtl_gwas_dir agree_direction Feature_Type
# 0     Up          Down              No         Gene
# 1     Up          Down              No         Gene

# %%
df.to_csv('BrainSeq_Phase3_Caudate_GWAS_DE_eQTL_Integration.txt.gz', index=False, header=True, sep='\t')
