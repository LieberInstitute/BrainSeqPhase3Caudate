# %%
# Leiden and igraph
import pandas as pd
import numpy as np
from sklearn.neighbors import kneighbors_graph
import igraph as ig
import leidenalg
import re
import scipy.stats as stats
from statsmodels.stats.multitest import multipletests


# Ensembl ID to Entrez ID conversion
import rpy2.robjects as ro
from rpy2.robjects import pandas2ri
from rpy2.robjects.conversion import localconverter


# GO analysis
from goatools.base import download_go_basic_obo
from goatools.base import download_ncbi_associations
from goatools.obo_parser import GODag
from goatools.anno.genetogo_reader import Gene2GoReader
from goatools.goea.go_enrichment_ns import GOEnrichmentStudyNS


# Word cloud
import wordcloud
import math
import random

# GTF parser for Ensembl ID to gene symbol conversion
from gtfparse import read_gtf

# %%
def latent_variables_to_leiden(df, n_neighbors, directed, seed):
    
    adjacency = kneighbors_graph(df, n_neighbors, mode='connectivity', include_self=False)
    
    distance = kneighbors_graph(df, n_neighbors, mode='distance', include_self=False)
    
    sources, targets = adjacency.nonzero()

    # weight is inverse distance squared

    weights = 1 /  distance[sources, targets].A1 ** 2

    
    g = ig.Graph(directed=directed)
    g.add_vertices(adjacency.shape[0])  # this adds adjacency.shape[0] vertices
    g.add_edges(list(zip(sources, targets)))
    g.es['weight'] = weights
    
    part = leidenalg.find_partition(g, leidenalg.ModularityVertexPartition, weights='weight', seed=seed)
    
    
    membership_df = pd.DataFrame({'cluster_id':part.membership}, index=df.index)
    
    return (membership_df, part)

# %%
# Ensembl to Entrez

class EnsemblIDToEntrezIDConverter():
    def __init__(self):
        with localconverter(ro.default_converter + pandas2ri.converter):
            df_a = ro.conversion.rpy2py(ro.r('''
                                             library(org.Hs.eg.db)
                                             as.data.frame(org.Hs.egENSEMBL)
                                            '''))
            self.entrez_ensembl_df = df_a.groupby(['ensembl_id']).first()
    
    def convert(self, gene_list_or_set):
        
        ensembl_id_df = pd.DataFrame(index = { re.sub("\..*$","",x) for x in gene_list_or_set })
        entrez_ids = set(ensembl_id_df.merge(self.entrez_ensembl_df, left_index=True, right_index=True)['gene_id'].astype(int))
        return entrez_ids
        
    
    
    
# Gene Ontology
    
def get_entrez_ensembl_df():
    with localconverter(ro.default_converter + pandas2ri.converter):
        df_a = ro.conversion.rpy2py(ro.r('''
                                         library(org.Hs.eg.db)
                                         as.data.frame(org.Hs.egENSEMBL)
                                        '''))
        entrez_ensembl_df = df_a.groupby(['ensembl_id']).first()
        return entrez_ensembl_df


class MyGeneOntologyAnalysis():
    def __init__(self):
        

        obo_fname = download_go_basic_obo()
        file_gene2go = download_ncbi_associations()
        obodag = GODag("go-basic.obo")

        # Read NCBI's gene2go. Store annotations in a list of namedtuples
        objanno = Gene2GoReader(file_gene2go, taxids=[9606])

        # Get associations for each branch of the GO DAG (BP, MF, CC)
        ns2assoc = objanno.get_ns2assc()

        for nspc, id2gos in ns2assoc.items():
            print("{NS} {N:,} annotated human genes".format(NS=nspc, N=len(id2gos)))
          
        genes_with_annotation = set.union(*(set(x.keys()) for x in ns2assoc.values()))

        
        self.alpha = 0.05
        
        self.goeaobj = GOEnrichmentStudyNS(
            genes_with_annotation, # List of human genes
            ns2assoc, # geneid/GO associations
            obodag, # Ontologies
            propagate_counts = False,
            alpha = self.alpha, # default significance cut-off
            methods = ['fdr_bh']) # defult multipletest correction method
        
        

    def goea_results_all(self, gene_set):
        return self.goeaobj.run_study(gene_set)
    
    
    def goea_results_significant(self, gene_set):
        all_results = self.goea_results_all(gene_set)
        return [r for r in all_results if r.p_fdr_bh < self.alpha]
    
    

# Word cloud
    
class GeneOntologyWordCloud():
    def __init__(self):
        self.wc = wordcloud.WordCloud(colormap='rainbow', 
                             stopwords=['integral', 'component', 'of', 'process', 'activity', 'to'],
                             collocations = True,
                             ranks_only=True,
                         )
        
    def gen_random_text(self):
        # Generate a spacer between gene ontology terms
        return ' '.join(''.join((random.choice('abcdefghijklmnopqrstuvwxyz') for _ in range(150))) for _ in range(3))
        
    def goea_to_text(self, goea_results):
        # Generate a text concatenating GO term names, each name being repeated proportionally to the minus log of its pvalue
        return ' '.join((''.join( ' ' + self.gen_random_text() + ' ' + x.name for _ in range(int((-10) * math.log2(x.p_uncorrected))))
                for x in goea_results  if x.enrichment == 'e'))
    
    def generate_image(self, goea_results):
        return self.wc.generate(self.goea_to_text(goea_results)).to_image()

# %%
def get_gtf_genes_df():
    try:
        gtf_df_genes = pd.read_csv("gtf_df_genes.csv")
    except:
        gtf_df = read_gtf("/ceph/genome/human/gencode25/gtf.CHR/_m/gencode.v25.annotation.gtf")
        gtf_df_genes = gtf_df[gtf_df["feature"] == "gene"][['gene_id', 'gene_name']]
        gtf_df_genes.to_csv("gtf_df_genes.csv", index=None)
        
    return gtf_df_genes

# %%
class ClusterGOWordCloud():
    def __init__(self, n_neighbors, directed, seed):
        
        self.n_neighbors = n_neighbors
        expression_df = pd.read_csv('../../_m/latent_variables.csv', index_col=0)
        mucols = [x for x in expression_df.columns if 'mu' in x]
        self.expression_df = expression_df[mucols]
        
        
        
        (self.mdf, self.part) =  latent_variables_to_leiden(self.expression_df, n_neighbors, directed, seed)
        
        
        self.gtf_df_genes = get_gtf_genes_df()

        self.e2e = EnsemblIDToEntrezIDConverter()
        self.mygoa = MyGeneOntologyAnalysis()
        self.gowc = GeneOntologyWordCloud()
    
    
    def cluster_df(self, cluster_id):
        
        return self.expression_df.iloc[self.part[cluster_id]][[]]\
        .merge(cgowc.gtf_df_genes, left_index=True, right_on='gene_id', how='left')\
        .set_index('gene_id')
        
    
    def pipeline(self, cluster_id, filename_prefix):
        
        #with open("%s_neighbors.txt" % filename_prefix, "wt") as f:
        #    for x in nn:
        #        print(x, file=f)

        #self.gn.neighbors_df(gene_id, self.n_neighbors)\
        #.to_csv("%s_neighbors.csv" % filename_prefix)
        
        #nn = self.gn.neighbors(gene_id, self.n_neighbors)
        
        self.cluster_df(cluster_id).to_csv("%s_genes.csv" % filename_prefix)
        
        nn = set((self.expression_df.index[x] for x in self.part[cluster_id]))
                
        go_r = self.mygoa.goea_results_significant(self.e2e.convert(nn))
        self.mygoa.goeaobj.wr_tsv("%s_go_enrichment.tsv" % filename_prefix, go_r)
        
        if len(go_r) > 0:
            p = self.gowc.generate_image(go_r)
            p.save("%s_go_wordcloud.png" % filename_prefix)

# %%
cgowc = ClusterGOWordCloud(8, False, 1092333)
# Out:
# /home/apua/.local/lib/python3.9/site-packages/gtfparse/read_gtf.py:151: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   result = parse_gtf(
# /home/apua/.local/lib/python3.9/site-packages/gtfparse/read_gtf.py:151: FutureWarning: The warn_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   result = parse_gtf(
# INFO:root:Extracted GTF attributes: ['gene_id', 'gene_type', 'gene_status', 'gene_name', 'level', 'havana_gene', 'transcript_id', 'transcript_type', 'transcript_status', 'transcript_name', 'transcript_support_level', 'tag', 'havana_transcript', 'exon_number', 'exon_id', 'ont', 'protein_id', 'ccdsid']
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Loading required package: AnnotationDbi
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Loading required package: stats4
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Loading required package: BiocGenerics
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Loading required package: parallel
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
# Attaching package: ‘BiocGenerics’
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Loading required package: Biobase
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Loading required package: IRanges
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Loading required package: S4Vectors
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
# Attaching package: ‘S4Vectors’
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
# requests.get(http://purl.obolibrary.org/obo/go/go-basic.obo, stream=True)
#   WROTE: go-basic.obo
#
# FTP RETR ftp.ncbi.nlm.nih.gov gene/DATA gene2go.gz -> gene2go.gz
#   gunzip gene2go.gz
# go-basic.obo: fmt(1.2) rel(2021-09-01) 47,191 GO Terms
# HMS:0:00:04.667423 330,404 annotations, 20,688 genes, 18,642 GOs, 1 taxids READ: gene2go
# MF 18,194 annotated human genes
# CC 19,433 annotated human genes
# BP 18,501 annotated human genes
#
# Load BP Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  90% 18,501 of 20,652 population items found in association
#
# Load CC Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  94% 19,433 of 20,652 population items found in association
#
# Load MF Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
#  88% 18,194 of 20,652 population items found in association

# %%
len(cgowc.part)
# Out:
# 20

# %%
a = [x for x in range(len(cgowc.part)) if 1 in cgowc.part[x]][0]
print("D2 junction 5-6 is in module", a)

a = [x for x in range(len(cgowc.part)) if 0 in cgowc.part[x]][0]
print("D2 junction 5-7 is in module", a)

d = {z[0]:z[1]  for z in zip(cgowc.gtf_df_genes['gene_name'], cgowc.gtf_df_genes['gene_id'])}
a = cgowc.mdf.loc[d['SETD1A'], 'cluster_id']
print("SETD1A is in module", a)

a = cgowc.mdf.loc[d['DRD2'], 'cluster_id']
print("DRD2 is in module", a)
# Out:
# D2 junction 5-6 is in module 0
# D2 junction 5-7 is in module 0
# SETD1A is in module 5
# DRD2 is in module 0

# %% [markdown]
# # GWAS, TWAS and DE enrichment

# %%
de_genes = set(pd.read_csv('/ceph/projects/v4_phase3_paper/analysis/differential_expression/_m/genes/diffExpr_szVctl_FDR05.txt',
                      sep='\t', usecols=[0], index_col=0).index)
len(de_genes)
# Out:
# 2696

# %%
def get_twas_genes():
    df = pd.read_csv('/ceph/projects/v4_phase3_paper/analysis/twas/results_tables/pgc2/_m/gene_twas_results_including_MHC.csv')
    return set(df[df['TWAS.P.fdr_bh'] < .05]['gene_id'])


twas_genes = get_twas_genes()
len(twas_genes)
# Out:
# 684

# %%
gwas_genes = set(pd.read_csv('/ceph/projects/v4_phase3_paper/inputs/sz_gwas/pgc2_clozuk/table_s3/hg38/genes/_m/gwas_genes.csv')['gene_id'])
len(gwas_genes)
# Out:
# 2000

# %%
mhc_genes = set(pd.read_csv('/ceph/projects/v4_phase3_paper/inputs/sz_gwas/pgc2_clozuk/table_s3/hg38/mhc_region_genes/_m/mhc_genes.csv')['gene_id'])
len(mhc_genes)
# Out:
# 383

# %%
def fet(a, b, u):
    # a, b, u are sets
    # u is the universe
    
    yes_a = u.intersection(a)
    yes_b = u.intersection(b)
    no_a = u - a
    no_b = u - b
    
    
    
    
    m = [[len(yes_a.intersection(yes_b)), len(no_a.intersection(yes_b)) ], 
                               [len(yes_a.intersection(no_b)), len(no_a.intersection(no_b))]]
    return stats.fisher_exact(m) #, m, len(yes_b)/len(u), len(yes_a)/len(u), len(yes_a.intersection(yes_b)) * len(no_a.intersection(no_b)) / (len(yes_a.intersection(no_b)) * len(no_a.intersection(yes_b)))

# %%
def enrichment_rows():
    part = cgowc.part
    df = cgowc.expression_df
    u = set(cgowc.expression_df.index[3:])
    for ii in range(len(part)):
        a = set((df.index[x] for x in part[ii]))
        yield (ii,
               len(part[ii]),
               *fet(a, gwas_genes, u),
               *fet(a, twas_genes, u),
               *fet(a, de_genes, u),
               )
        
    #print(ii, 0 in part[ii], 1 in part[ii], fet(a, gwas_genes, u), fet(a, twas_genes, u), fet(a, de_genes, u), len(part[ii]))
    
edf1 = pd.DataFrame.from_records(enrichment_rows(), 
                                 columns=['module_id', 'n_genes', 'gwas_or', 'gwas_p', 'twas_or', 'twas_p', 'de_or', 'de_p'],
                                 index='module_id')
edf1['twas_fdr_bh'] = multipletests(edf1['twas_p'], method='fdr_bh')[1]
edf1['gwas_fdr_bh'] = multipletests(edf1['gwas_p'], method='fdr_bh')[1]
edf1['de_fdr_bh'] = multipletests(edf1['de_p'], method='fdr_bh')[1]

edf1[['n_genes', 'gwas_or', 'gwas_p', 'gwas_fdr_bh', 'twas_or', 'twas_p', 'twas_fdr_bh', 'de_or', 'de_p', 'de_fdr_bh']].to_csv('module_enrichment.csv')

edf1
# Out:
#            n_genes   gwas_or    gwas_p   twas_or    twas_p     de_or  \
# module_id
# 0             4932  1.195380  0.017789  1.515280  0.000007  2.970279
# 1             3681  0.977286  0.827135  0.569069  0.000021  0.343346
# 2             3047  1.048770  0.602387  1.686867  0.000001  1.204706
# 3             2688  1.110855  0.270985  1.294817  0.032309  0.957064
# 4             1533  1.046916  0.697807  0.839276  0.401404  0.908283
# 5             1488  1.170352  0.211855  1.185547  0.269657  1.559550
# 6             1353  0.471844  0.000014  0.564796  0.009668  1.069158
# 7             1157  0.722880  0.054457  0.494499  0.003970  0.183562
# 8             1103  0.545154  0.001089  0.556236  0.018219  0.201529
# 9             1047  1.116042  0.438109  0.860136  0.547137  0.160597
# 10             871  1.010937  0.932394  0.713797  0.226131  0.184693
# 11             795  0.989432  1.000000  0.532632  0.037915  0.407333
# 12             697  0.925349  0.776935  0.843455  0.624397  3.813977
# 13             554  0.826667  0.460277  0.416404  0.027279  0.229651
# 14             454  1.997844  0.000249  1.510976  0.097231  0.200021
# 15             354  1.049345  0.792376  0.436736  0.121018  0.232567
# 16             266  0.335891  0.021310  0.887646  1.000000  0.498185
# 17             186  1.127417  0.715198  1.064241  0.813045  0.196921
# 18             157  0.577684  0.425910  1.268719  0.603295  0.234532
# 19             150  0.762855  0.688923  0.784920  1.000000  2.562200
#
#                     de_p  twas_fdr_bh  gwas_fdr_bh      de_fdr_bh
# module_id
# 0          1.148426e-124     0.000073     0.085240  2.296851e-123
# 1           3.497782e-46     0.000137     0.919039   3.497782e-45
# 2           2.526951e-03     0.000030     0.919039   3.158689e-03
# 3           5.414012e-01     0.080773     0.677462   5.414012e-01
# 4           3.126862e-01     0.573434     0.919039   3.474292e-01
# 5           3.047559e-08     0.414857     0.605301   5.541017e-08
# 6           4.564584e-01     0.038673     0.000275   4.804825e-01
# 7           3.232025e-27     0.019850     0.181522   1.616013e-26
# 8           1.279795e-24     0.060729     0.007257   4.265982e-24
# 9           9.165784e-27     0.729516     0.836868   3.666314e-26
# 10          1.073003e-20     0.376884     0.981467   3.065723e-20
# 11          6.069822e-09     0.084256     1.000000   1.213964e-08
# 12          1.735665e-44     0.734585     0.919039   1.157110e-43
# 13          8.001289e-12     0.077939     0.836868   2.000322e-11
# 14          7.642308e-11     0.194461     0.002492   1.698291e-10
# 15          8.607329e-08     0.220033     0.919039   1.434555e-07
# 16          7.312715e-03     1.000000     0.085240   8.603194e-03
# 17          6.227493e-05     0.903383     0.919039   8.896418e-05
# 18          6.879887e-04     0.734585     0.836868   9.173182e-04
# 19          1.301102e-05     1.000000     0.919039   2.001696e-05

# %%
def enrichment_rows_nomhc():
    part = cgowc.part
    df = cgowc.expression_df
    u = set(cgowc.expression_df.index[3:]) - mhc_genes
    for ii in range(len(part)):
        a = set((df.index[x] for x in part[ii])) - mhc_genes
        yield (ii,
               len(part[ii]),
               *fet(a, gwas_genes - mhc_genes, u),
               *fet(a, twas_genes - mhc_genes, u),
               *fet(a, de_genes - mhc_genes, u),
              )
        
    #print(ii, 0 in part[ii], 1 in part[ii], fet(a, gwas_genes, u), fet(a, twas_genes, u), fet(a, de_genes, u), len(part[ii]))
    
edf2 = pd.DataFrame.from_records(enrichment_rows_nomhc(), 
                                columns=['module_id', 'n_genes', 'gwas_or', 'gwas_p', 'twas_or', 'twas_p', 'de_or', 'de_p'],
                                index='module_id')
edf2['twas_fdr_bh'] = multipletests(edf2['twas_p'], method='fdr_bh')[1]
edf2['gwas_fdr_bh'] = multipletests(edf2['gwas_p'], method='fdr_bh')[1]
edf2['de_fdr_bh'] = multipletests(edf2['de_p'], method='fdr_bh')[1]

edf2[['n_genes', 'gwas_or', 'gwas_p', 'gwas_fdr_bh', 'twas_or', 'twas_p', 'twas_fdr_bh', 'de_or', 'de_p', 'de_fdr_bh']].to_csv('module_enrichment_excluding_mhc_region.csv')

edf2
# Out:
#            n_genes   gwas_or    gwas_p   twas_or        twas_p     de_or  \
# module_id
# 0             4932  1.270454  0.003104  1.549287  5.867860e-06  2.961945
# 1             3681  1.020123  0.812521  0.519681  3.626710e-06  0.345171
# 2             3047  1.089280  0.381779  1.766923  3.520444e-07  1.195410
# 3             2688  1.114344  0.300997  1.381112  9.880629e-03  0.951603
# 4             1533  0.838594  0.288888  0.693205  7.838740e-02  0.915592
# 5             1488  1.166873  0.252847  1.245411  1.818538e-01  1.565331
# 6             1353  0.524344  0.000442  0.585507  2.007082e-02  1.070443
# 7             1157  0.768958  0.148966  0.467050  3.603034e-03  0.184092
# 8             1103  0.454820  0.000199  0.532590  1.788755e-02  0.202944
# 9             1047  0.977653  1.000000  0.821551  4.609709e-01  0.162616
# 10             871  1.078994  0.645156  0.783014  4.214106e-01  0.185456
# 11             795  1.076547  0.699904  0.583337  9.202699e-02  0.408722
# 12             697  1.025411  0.837970  0.859146  7.015372e-01  3.800434
# 13             554  0.886653  0.730527  0.455637  4.576318e-02  0.230371
# 14             454  1.270219  0.301717  1.084679  7.479606e-01  0.208002
# 15             354  1.172825  0.565691  0.477367  1.549964e-01  0.233109
# 16             266  0.299728  0.020586  0.971485  1.000000e+00  0.499903
# 17             186  0.743496  0.690608  0.701575  8.031866e-01  0.201263
# 18             157  0.515488  0.386225  1.104572  7.864634e-01  0.235950
# 19             150  0.908731  1.000000  0.855370  1.000000e+00  2.560943
#
#                     de_p  twas_fdr_bh  gwas_fdr_bh      de_fdr_bh
# module_id
# 0          2.549525e-123     0.000039     0.020695  5.099050e-122
# 1           1.176488e-45     0.000036     0.931078   1.176488e-44
# 2           4.129949e-03     0.000007     0.702226   5.162436e-03
# 3           4.958298e-01     0.039523     0.670483   4.958298e-01
# 4           3.534987e-01     0.174194     0.670483   3.927763e-01
# 5           2.673936e-08     0.303090     0.670483   4.861702e-08
# 6           4.560327e-01     0.057345     0.004420   4.800344e-01
# 7           3.015561e-27     0.018015     0.595863   1.507781e-26
# 8           2.563420e-24     0.057345     0.003987   8.544733e-24
# 9           2.728412e-26     0.658530     1.000000   1.091365e-25
# 10          1.543271e-20     0.648324     0.913159   4.409344e-20
# 11          5.968394e-09     0.184054     0.913159   1.193679e-08
# 12          4.331722e-44     0.892430     0.931078   2.887815e-43
# 13          1.151085e-11     0.114408     0.913159   2.877712e-11
# 14          3.064875e-10     0.892430     0.670483   6.810834e-10
# 15          8.470326e-08     0.281812     0.913159   1.411721e-07
# 16          7.306296e-03     1.000000     0.102931   8.595642e-03
# 17          8.869142e-05     0.892430     0.913159   1.267020e-04
# 18          6.739618e-04     0.892430     0.702226   8.986157e-04
# 19          1.309510e-05     1.000000     1.000000   2.014631e-05

# %% [markdown]
# # GO enrichment for each cluster

# %%
# Run pipeline for each cluster
for cluster_id in range(len(cgowc.part)):
    cgowc.pipeline(cluster_id, 'module%d' % cluster_id)
# Out:
# Run BP Gene Ontology Analysis: current study set of 4806 IDs ... 94%  4,412 of  4,685 study items found in association
#  97%  4,685 of  4,806 study items found in population(20652)
# Calculating 12,417 uncorrected p-values using fisher_scipy_stats
#   12,417 GO terms are associated with 18,501 of 20,652 population items
#    7,819 GO terms are associated with  4,412 of  4,806 study items
#   METHOD fdr_bh:
#      387 GO terms found significant (< 0.05=alpha) (361 enriched +  26 purified): statsmodels fdr_bh
#    3,261 study items associated with significant GO IDs (enriched)
#      583 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 4806 IDs ... 98%  4,583 of  4,685 study items found in association
#  97%  4,685 of  4,806 study items found in population(20652)
# Calculating 1,754 uncorrected p-values using fisher_scipy_stats
#    1,754 GO terms are associated with 19,433 of 20,652 population items
#    1,296 GO terms are associated with  4,583 of  4,806 study items
#   METHOD fdr_bh:
#      297 GO terms found significant (< 0.05=alpha) (284 enriched +  13 purified): statsmodels fdr_bh
#    4,412 study items associated with significant GO IDs (enriched)
#      492 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 4806 IDs ... 95%  4,459 of  4,685 study items found in association
#  97%  4,685 of  4,806 study items found in population(20652)
# Calculating 4,419 uncorrected p-values using fisher_scipy_stats
#    4,419 GO terms are associated with 18,194 of 20,652 population items
#    2,456 GO terms are associated with  4,459 of  4,806 study items
#   METHOD fdr_bh:
#      163 GO terms found significant (< 0.05=alpha) (143 enriched +  20 purified): statsmodels fdr_bh
#    4,070 study items associated with significant GO IDs (enriched)
#      329 study items associated with significant GO IDs (purified)
#     847 items WROTE: module0_go_enrichment.tsv
#
# Run BP Gene Ontology Analysis: current study set of 1869 IDs ... 88%    588 of    672 study items found in association
#  36%    672 of  1,869 study items found in population(20652)
# Calculating 12,417 uncorrected p-values using fisher_scipy_stats
#   12,417 GO terms are associated with 18,501 of 20,652 population items
#    1,463 GO terms are associated with    588 of  1,869 study items
#   METHOD fdr_bh:
#        6 GO terms found significant (< 0.05=alpha) (  5 enriched +   1 purified): statsmodels fdr_bh
#      229 study items associated with significant GO IDs (enriched)
#        8 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 1869 IDs ... 84%    562 of    672 study items found in association
#  36%    672 of  1,869 study items found in population(20652)
# Calculating 1,754 uncorrected p-values using fisher_scipy_stats
#    1,754 GO terms are associated with 19,433 of 20,652 population items
#      331 GO terms are associated with    562 of  1,869 study items
#   METHOD fdr_bh:
#       14 GO terms found significant (< 0.05=alpha) (  2 enriched +  12 purified): statsmodels fdr_bh
#      109 study items associated with significant GO IDs (enriched)
#      334 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 1869 IDs ... 64%    430 of    672 study items found in association
#  36%    672 of  1,869 study items found in population(20652)
# Calculating 4,419 uncorrected p-values using fisher_scipy_stats
#    4,419 GO terms are associated with 18,194 of 20,652 population items
#      498 GO terms are associated with    430 of  1,869 study items
#   METHOD fdr_bh:
#        5 GO terms found significant (< 0.05=alpha) (  3 enriched +   2 purified): statsmodels fdr_bh
#       61 study items associated with significant GO IDs (enriched)
#      240 study items associated with significant GO IDs (purified)
#      25 items WROTE: module1_go_enrichment.tsv
#
# Run BP Gene Ontology Analysis: current study set of 2851 IDs ... 91%  2,426 of  2,671 study items found in association
#  94%  2,671 of  2,851 study items found in population(20652)
# Calculating 12,417 uncorrected p-values using fisher_scipy_stats
#   12,417 GO terms are associated with 18,501 of 20,652 population items
#    4,940 GO terms are associated with  2,426 of  2,851 study items
#   METHOD fdr_bh:
#       57 GO terms found significant (< 0.05=alpha) ( 31 enriched +  26 purified): statsmodels fdr_bh
#      951 study items associated with significant GO IDs (enriched)
#      244 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 2851 IDs ... 95%  2,537 of  2,671 study items found in association
#  94%  2,671 of  2,851 study items found in population(20652)
# Calculating 1,754 uncorrected p-values using fisher_scipy_stats
#    1,754 GO terms are associated with 19,433 of 20,652 population items
#      914 GO terms are associated with  2,537 of  2,851 study items
#   METHOD fdr_bh:
#       87 GO terms found significant (< 0.05=alpha) ( 59 enriched +  28 purified): statsmodels fdr_bh
#    2,124 study items associated with significant GO IDs (enriched)
#      847 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 2851 IDs ... 95%  2,526 of  2,671 study items found in association
#  94%  2,671 of  2,851 study items found in population(20652)
# Calculating 4,419 uncorrected p-values using fisher_scipy_stats
#    4,419 GO terms are associated with 18,194 of 20,652 population items
#    1,688 GO terms are associated with  2,526 of  2,851 study items
#   METHOD fdr_bh:
#       35 GO terms found significant (< 0.05=alpha) ( 16 enriched +  19 purified): statsmodels fdr_bh
#    2,209 study items associated with significant GO IDs (enriched)
#      137 study items associated with significant GO IDs (purified)
#     179 items WROTE: module2_go_enrichment.tsv
#
# Run BP Gene Ontology Analysis: current study set of 2024 IDs ... 88%  1,443 of  1,633 study items found in association
#  81%  1,633 of  2,024 study items found in population(20652)
# Calculating 12,417 uncorrected p-values using fisher_scipy_stats
#   12,417 GO terms are associated with 18,501 of 20,652 population items
#    3,370 GO terms are associated with  1,443 of  2,024 study items
#   METHOD fdr_bh:
#       11 GO terms found significant (< 0.05=alpha) (  4 enriched +   7 purified): statsmodels fdr_bh
#      280 study items associated with significant GO IDs (enriched)
#       85 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 2024 IDs ... 94%  1,536 of  1,633 study items found in association
#  81%  1,633 of  2,024 study items found in population(20652)
# Calculating 1,754 uncorrected p-values using fisher_scipy_stats
#    1,754 GO terms are associated with 19,433 of 20,652 population items
#      664 GO terms are associated with  1,536 of  2,024 study items
#   METHOD fdr_bh:
#       21 GO terms found significant (< 0.05=alpha) (  5 enriched +  16 purified): statsmodels fdr_bh
#      685 study items associated with significant GO IDs (enriched)
#      529 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 2024 IDs ... 92%  1,507 of  1,633 study items found in association
#  81%  1,633 of  2,024 study items found in population(20652)
# Calculating 4,419 uncorrected p-values using fisher_scipy_stats
#    4,419 GO terms are associated with 18,194 of 20,652 population items
#    1,270 GO terms are associated with  1,507 of  2,024 study items
#   METHOD fdr_bh:
#       11 GO terms found significant (< 0.05=alpha) (  6 enriched +   5 purified): statsmodels fdr_bh
#      364 study items associated with significant GO IDs (enriched)
#       14 study items associated with significant GO IDs (purified)
#      43 items WROTE: module3_go_enrichment.tsv
#
# Run BP Gene Ontology Analysis: current study set of 1384 IDs ... 92%  1,188 of  1,294 study items found in association
#  93%  1,294 of  1,384 study items found in population(20652)
# Calculating 12,417 uncorrected p-values using fisher_scipy_stats
#   12,417 GO terms are associated with 18,501 of 20,652 population items
#    4,356 GO terms are associated with  1,188 of  1,384 study items
#   METHOD fdr_bh:
#      110 GO terms found significant (< 0.05=alpha) (105 enriched +   5 purified): statsmodels fdr_bh
#      706 study items associated with significant GO IDs (enriched)
#       10 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 1384 IDs ... 97%  1,249 of  1,294 study items found in association
#  93%  1,294 of  1,384 study items found in population(20652)
# Calculating 1,754 uncorrected p-values using fisher_scipy_stats
#    1,754 GO terms are associated with 19,433 of 20,652 population items
#      555 GO terms are associated with  1,249 of  1,384 study items
#   METHOD fdr_bh:
#       30 GO terms found significant (< 0.05=alpha) ( 28 enriched +   2 purified): statsmodels fdr_bh
#    1,063 study items associated with significant GO IDs (enriched)
#       41 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 1384 IDs ... 94%  1,210 of  1,294 study items found in association
#  93%  1,294 of  1,384 study items found in population(20652)
# Calculating 4,419 uncorrected p-values using fisher_scipy_stats
#    4,419 GO terms are associated with 18,194 of 20,652 population items
#    1,231 GO terms are associated with  1,210 of  1,384 study items
#   METHOD fdr_bh:
#       27 GO terms found significant (< 0.05=alpha) ( 23 enriched +   4 purified): statsmodels fdr_bh
#      968 study items associated with significant GO IDs (enriched)
#       55 study items associated with significant GO IDs (purified)
#     167 items WROTE: module4_go_enrichment.tsv
#
# Run BP Gene Ontology Analysis: current study set of 1375 IDs ... 91%  1,164 of  1,281 study items found in association
#  93%  1,281 of  1,375 study items found in population(20652)
# Calculating 12,417 uncorrected p-values using fisher_scipy_stats
#   12,417 GO terms are associated with 18,501 of 20,652 population items
#    3,377 GO terms are associated with  1,164 of  1,375 study items
#   METHOD fdr_bh:
#        8 GO terms found significant (< 0.05=alpha) (  1 enriched +   7 purified): statsmodels fdr_bh
#        5 study items associated with significant GO IDs (enriched)
#       25 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 1375 IDs ... 96%  1,235 of  1,281 study items found in association
#  93%  1,281 of  1,375 study items found in population(20652)
# Calculating 1,754 uncorrected p-values using fisher_scipy_stats
#    1,754 GO terms are associated with 19,433 of 20,652 population items
#      638 GO terms are associated with  1,235 of  1,375 study items
#   METHOD fdr_bh:
#       22 GO terms found significant (< 0.05=alpha) ( 13 enriched +   9 purified): statsmodels fdr_bh
#      902 study items associated with significant GO IDs (enriched)
#      422 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 1375 IDs ... 93%  1,191 of  1,281 study items found in association
#  93%  1,281 of  1,375 study items found in population(20652)
# Calculating 4,419 uncorrected p-values using fisher_scipy_stats
#    4,419 GO terms are associated with 18,194 of 20,652 population items
#    1,056 GO terms are associated with  1,191 of  1,375 study items
#   METHOD fdr_bh:
#        7 GO terms found significant (< 0.05=alpha) (  4 enriched +   3 purified): statsmodels fdr_bh
#      994 study items associated with significant GO IDs (enriched)
#        3 study items associated with significant GO IDs (purified)
#      37 items WROTE: module5_go_enrichment.tsv
#
# Run BP Gene Ontology Analysis: current study set of 779 IDs ... 89%    409 of    461 study items found in association
#  59%    461 of    779 study items found in population(20652)
# Calculating 12,417 uncorrected p-values using fisher_scipy_stats
#   12,417 GO terms are associated with 18,501 of 20,652 population items
#    1,724 GO terms are associated with    409 of    779 study items
#   METHOD fdr_bh:
#        6 GO terms found significant (< 0.05=alpha) (  6 enriched +   0 purified): statsmodels fdr_bh
#       47 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 779 IDs ... 94%    434 of    461 study items found in association
#  59%    461 of    779 study items found in population(20652)
# Calculating 1,754 uncorrected p-values using fisher_scipy_stats
#    1,754 GO terms are associated with 19,433 of 20,652 population items
#      308 GO terms are associated with    434 of    779 study items
#   METHOD fdr_bh:
#        9 GO terms found significant (< 0.05=alpha) (  7 enriched +   2 purified): statsmodels fdr_bh
#      172 study items associated with significant GO IDs (enriched)
#       99 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 779 IDs ... 90%    415 of    461 study items found in association
#  59%    461 of    779 study items found in population(20652)
# Calculating 4,419 uncorrected p-values using fisher_scipy_stats
#    4,419 GO terms are associated with 18,194 of 20,652 population items
#      565 GO terms are associated with    415 of    779 study items
#   METHOD fdr_bh:
#        5 GO terms found significant (< 0.05=alpha) (  4 enriched +   1 purified): statsmodels fdr_bh
#       19 study items associated with significant GO IDs (enriched)
#       10 study items associated with significant GO IDs (purified)
#      20 items WROTE: module6_go_enrichment.tsv
#
# Run BP Gene Ontology Analysis: current study set of 493 IDs ... 89%    108 of    122 study items found in association
#  25%    122 of    493 study items found in population(20652)
# Calculating 12,417 uncorrected p-values using fisher_scipy_stats
#   12,417 GO terms are associated with 18,501 of 20,652 population items
#      393 GO terms are associated with    108 of    493 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#       21 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 493 IDs ... 80%     98 of    122 study items found in association
#  25%    122 of    493 study items found in population(20652)
# Calculating 1,754 uncorrected p-values using fisher_scipy_stats
#    1,754 GO terms are associated with 19,433 of 20,652 population items
#      100 GO terms are associated with     98 of    493 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  0 enriched +   1 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        8 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 493 IDs ... 72%     88 of    122 study items found in association
#  25%    122 of    493 study items found in population(20652)
# Calculating 4,419 uncorrected p-values using fisher_scipy_stats
#    4,419 GO terms are associated with 18,194 of 20,652 population items
#      165 GO terms are associated with     88 of    493 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  0 enriched +   1 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#       45 study items associated with significant GO IDs (purified)
#       3 items WROTE: module7_go_enrichment.tsv
#
# Run BP Gene Ontology Analysis: current study set of 711 IDs ... 88%    428 of    485 study items found in association
#  68%    485 of    711 study items found in population(20652)
# Calculating 12,417 uncorrected p-values using fisher_scipy_stats
#   12,417 GO terms are associated with 18,501 of 20,652 population items
#    2,094 GO terms are associated with    428 of    711 study items
#   METHOD fdr_bh:
#        3 GO terms found significant (< 0.05=alpha) (  3 enriched +   0 purified): statsmodels fdr_bh
#       24 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 711 IDs ... 95%    460 of    485 study items found in association
#  68%    485 of    711 study items found in population(20652)
# Calculating 1,754 uncorrected p-values using fisher_scipy_stats
#    1,754 GO terms are associated with 19,433 of 20,652 population items
#      359 GO terms are associated with    460 of    711 study items
#   METHOD fdr_bh:
#       12 GO terms found significant (< 0.05=alpha) (  9 enriched +   3 purified): statsmodels fdr_bh
#      260 study items associated with significant GO IDs (enriched)
#      118 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 711 IDs ... 92%    448 of    485 study items found in association
#  68%    485 of    711 study items found in population(20652)
# Calculating 4,419 uncorrected p-values using fisher_scipy_stats
#    4,419 GO terms are associated with 18,194 of 20,652 population items
#      594 GO terms are associated with    448 of    711 study items
#   METHOD fdr_bh:
#        4 GO terms found significant (< 0.05=alpha) (  4 enriched +   0 purified): statsmodels fdr_bh
#       26 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#      19 items WROTE: module8_go_enrichment.tsv
#
# Run BP Gene Ontology Analysis: current study set of 491 IDs ... 85%    221 of    260 study items found in association
#  53%    260 of    491 study items found in population(20652)
# Calculating 12,417 uncorrected p-values using fisher_scipy_stats
#   12,417 GO terms are associated with 18,501 of 20,652 population items
#    1,013 GO terms are associated with    221 of    491 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 491 IDs ... 90%    233 of    260 study items found in association
#  53%    260 of    491 study items found in population(20652)
# Calculating 1,754 uncorrected p-values using fisher_scipy_stats
#    1,754 GO terms are associated with 19,433 of 20,652 population items
#      223 GO terms are associated with    233 of    491 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 491 IDs ... 84%    218 of    260 study items found in association
#  53%    260 of    491 study items found in population(20652)
# Calculating 4,419 uncorrected p-values using fisher_scipy_stats
#    4,419 GO terms are associated with 18,194 of 20,652 population items
#      318 GO terms are associated with    218 of    491 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#       14 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#       1 items WROTE: module9_go_enrichment.tsv
#
# Run BP Gene Ontology Analysis: current study set of 462 IDs ... 88%    202 of    230 study items found in association
#  50%    230 of    462 study items found in population(20652)
# Calculating 12,417 uncorrected p-values using fisher_scipy_stats
#   12,417 GO terms are associated with 18,501 of 20,652 population items
#      875 GO terms are associated with    202 of    462 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 462 IDs ... 92%    211 of    230 study items found in association
#  50%    230 of    462 study items found in population(20652)
# Calculating 1,754 uncorrected p-values using fisher_scipy_stats
#    1,754 GO terms are associated with 19,433 of 20,652 population items
#      206 GO terms are associated with    211 of    462 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 462 IDs ... 87%    201 of    230 study items found in association
#  50%    230 of    462 study items found in population(20652)
# Calculating 4,419 uncorrected p-values using fisher_scipy_stats
#    4,419 GO terms are associated with 18,194 of 20,652 population items
#      301 GO terms are associated with    201 of    462 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#       0 items. NOT WRITING module10_go_enrichment.tsv
#
# Run BP Gene Ontology Analysis: current study set of 428 IDs ... 88%    224 of    254 study items found in association
#  59%    254 of    428 study items found in population(20652)
# Calculating 12,417 uncorrected p-values using fisher_scipy_stats
#   12,417 GO terms are associated with 18,501 of 20,652 population items
#    1,253 GO terms are associated with    224 of    428 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 428 IDs ... 94%    238 of    254 study items found in association
#  59%    254 of    428 study items found in population(20652)
# Calculating 1,754 uncorrected p-values using fisher_scipy_stats
#    1,754 GO terms are associated with 19,433 of 20,652 population items
#      227 GO terms are associated with    238 of    428 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 428 IDs ... 92%    233 of    254 study items found in association
#  59%    254 of    428 study items found in population(20652)
# Calculating 4,419 uncorrected p-values using fisher_scipy_stats
#    4,419 GO terms are associated with 18,194 of 20,652 population items
#      353 GO terms are associated with    233 of    428 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#       0 items. NOT WRITING module11_go_enrichment.tsv
#
# Run BP Gene Ontology Analysis: current study set of 513 IDs ... 90%    341 of    378 study items found in association
#  74%    378 of    513 study items found in population(20652)
# Calculating 12,417 uncorrected p-values using fisher_scipy_stats
#   12,417 GO terms are associated with 18,501 of 20,652 population items
#    1,536 GO terms are associated with    341 of    513 study items
#   METHOD fdr_bh:
#        9 GO terms found significant (< 0.05=alpha) (  9 enriched +   0 purified): statsmodels fdr_bh
#       51 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 513 IDs ... 94%    357 of    378 study items found in association
#  74%    378 of    513 study items found in population(20652)
# Calculating 1,754 uncorrected p-values using fisher_scipy_stats
#    1,754 GO terms are associated with 19,433 of 20,652 population items
#      328 GO terms are associated with    357 of    513 study items
#   METHOD fdr_bh:
#       12 GO terms found significant (< 0.05=alpha) ( 10 enriched +   2 purified): statsmodels fdr_bh
#      179 study items associated with significant GO IDs (enriched)
#       78 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 513 IDs ... 91%    344 of    378 study items found in association
#  74%    378 of    513 study items found in population(20652)
# Calculating 4,419 uncorrected p-values using fisher_scipy_stats
#    4,419 GO terms are associated with 18,194 of 20,652 population items
#      533 GO terms are associated with    344 of    513 study items
#   METHOD fdr_bh:
#        4 GO terms found significant (< 0.05=alpha) (  3 enriched +   1 purified): statsmodels fdr_bh
#       12 study items associated with significant GO IDs (enriched)
#        7 study items associated with significant GO IDs (purified)
#      25 items WROTE: module12_go_enrichment.tsv
#
# Run BP Gene Ontology Analysis: current study set of 250 IDs ... 83%     60 of     72 study items found in association
#  29%     72 of    250 study items found in population(20652)
# Calculating 12,417 uncorrected p-values using fisher_scipy_stats
#   12,417 GO terms are associated with 18,501 of 20,652 population items
#      300 GO terms are associated with     60 of    250 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 250 IDs ... 93%     67 of     72 study items found in association
#  29%     72 of    250 study items found in population(20652)
# Calculating 1,754 uncorrected p-values using fisher_scipy_stats
#    1,754 GO terms are associated with 19,433 of 20,652 population items
#       94 GO terms are associated with     67 of    250 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 250 IDs ... 74%     53 of     72 study items found in association
#  29%     72 of    250 study items found in population(20652)
# Calculating 4,419 uncorrected p-values using fisher_scipy_stats
#    4,419 GO terms are associated with 18,194 of 20,652 population items
#      118 GO terms are associated with     53 of    250 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#       0 items. NOT WRITING module13_go_enrichment.tsv
#
# Run BP Gene Ontology Analysis: current study set of 386 IDs ... 91%    301 of    329 study items found in association
#  85%    329 of    386 study items found in population(20652)
# Calculating 12,417 uncorrected p-values using fisher_scipy_stats
#   12,417 GO terms are associated with 18,501 of 20,652 population items
#    1,898 GO terms are associated with    301 of    386 study items
#   METHOD fdr_bh:
#      197 GO terms found significant (< 0.05=alpha) (195 enriched +   2 purified): statsmodels fdr_bh
#      237 study items associated with significant GO IDs (enriched)
#       10 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 386 IDs ... 99%    325 of    329 study items found in association
#  85%    329 of    386 study items found in population(20652)
# Calculating 1,754 uncorrected p-values using fisher_scipy_stats
#    1,754 GO terms are associated with 19,433 of 20,652 population items
#      271 GO terms are associated with    325 of    386 study items
#   METHOD fdr_bh:
#       41 GO terms found significant (< 0.05=alpha) ( 41 enriched +   0 purified): statsmodels fdr_bh
#      263 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 386 IDs ... 94%    309 of    329 study items found in association
#  85%    329 of    386 study items found in population(20652)
# Calculating 4,419 uncorrected p-values using fisher_scipy_stats
#    4,419 GO terms are associated with 18,194 of 20,652 population items
#      507 GO terms are associated with    309 of    386 study items
#   METHOD fdr_bh:
#       34 GO terms found significant (< 0.05=alpha) ( 34 enriched +   0 purified): statsmodels fdr_bh
#      269 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#     272 items WROTE: module14_go_enrichment.tsv
#
# Run BP Gene Ontology Analysis: current study set of 162 IDs ... 80%     57 of     71 study items found in association
#  44%     71 of    162 study items found in population(20652)
# Calculating 12,417 uncorrected p-values using fisher_scipy_stats
#   12,417 GO terms are associated with 18,501 of 20,652 population items
#      223 GO terms are associated with     57 of    162 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 162 IDs ... 92%     65 of     71 study items found in association
#  44%     71 of    162 study items found in population(20652)
# Calculating 1,754 uncorrected p-values using fisher_scipy_stats
#    1,754 GO terms are associated with 19,433 of 20,652 population items
#       71 GO terms are associated with     65 of    162 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 162 IDs ... 80%     57 of     71 study items found in association
#  44%     71 of    162 study items found in population(20652)
# Calculating 4,419 uncorrected p-values using fisher_scipy_stats
#    4,419 GO terms are associated with 18,194 of 20,652 population items
#       95 GO terms are associated with     57 of    162 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#       0 items. NOT WRITING module15_go_enrichment.tsv
#
# Run BP Gene Ontology Analysis: current study set of 229 IDs ... 82%    152 of    186 study items found in association
#  81%    186 of    229 study items found in population(20652)
# Calculating 12,417 uncorrected p-values using fisher_scipy_stats
#   12,417 GO terms are associated with 18,501 of 20,652 population items
#      842 GO terms are associated with    152 of    229 study items
#   METHOD fdr_bh:
#       19 GO terms found significant (< 0.05=alpha) ( 19 enriched +   0 purified): statsmodels fdr_bh
#       59 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 229 IDs ... 91%    170 of    186 study items found in association
#  81%    186 of    229 study items found in population(20652)
# Calculating 1,754 uncorrected p-values using fisher_scipy_stats
#    1,754 GO terms are associated with 19,433 of 20,652 population items
#      183 GO terms are associated with    170 of    229 study items
#   METHOD fdr_bh:
#       20 GO terms found significant (< 0.05=alpha) ( 16 enriched +   4 purified): statsmodels fdr_bh
#       76 study items associated with significant GO IDs (enriched)
#       51 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 229 IDs ... 84%    157 of    186 study items found in association
#  81%    186 of    229 study items found in population(20652)
# Calculating 4,419 uncorrected p-values using fisher_scipy_stats
#    4,419 GO terms are associated with 18,194 of 20,652 population items
#      224 GO terms are associated with    157 of    229 study items
#   METHOD fdr_bh:
#        6 GO terms found significant (< 0.05=alpha) (  5 enriched +   1 purified): statsmodels fdr_bh
#       19 study items associated with significant GO IDs (enriched)
#        1 study items associated with significant GO IDs (purified)
#      45 items WROTE: module16_go_enrichment.tsv
#
# Run BP Gene Ontology Analysis: current study set of 157 IDs ... 99%    132 of    133 study items found in association
#  85%    133 of    157 study items found in population(20652)
# Calculating 12,417 uncorrected p-values using fisher_scipy_stats
#   12,417 GO terms are associated with 18,501 of 20,652 population items
#      307 GO terms are associated with    132 of    157 study items
#   METHOD fdr_bh:
#       15 GO terms found significant (< 0.05=alpha) ( 14 enriched +   1 purified): statsmodels fdr_bh
#      110 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 157 IDs ... 98%    131 of    133 study items found in association
#  85%    133 of    157 study items found in population(20652)
# Calculating 1,754 uncorrected p-values using fisher_scipy_stats
#    1,754 GO terms are associated with 19,433 of 20,652 population items
#      115 GO terms are associated with    131 of    157 study items
#   METHOD fdr_bh:
#       26 GO terms found significant (< 0.05=alpha) ( 23 enriched +   3 purified): statsmodels fdr_bh
#      124 study items associated with significant GO IDs (enriched)
#       14 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 157 IDs ... 68%     90 of    133 study items found in association
#  85%    133 of    157 study items found in population(20652)
# Calculating 4,419 uncorrected p-values using fisher_scipy_stats
#    4,419 GO terms are associated with 18,194 of 20,652 population items
#      100 GO terms are associated with     90 of    157 study items
#   METHOD fdr_bh:
#        9 GO terms found significant (< 0.05=alpha) (  9 enriched +   0 purified): statsmodels fdr_bh
#       70 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#      50 items WROTE: module17_go_enrichment.tsv
#
# Run BP Gene Ontology Analysis: current study set of 97 IDs ... 80%     33 of     41 study items found in association
#  42%     41 of     97 study items found in population(20652)
# Calculating 12,417 uncorrected p-values using fisher_scipy_stats
#   12,417 GO terms are associated with 18,501 of 20,652 population items
#      196 GO terms are associated with     33 of     97 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 97 IDs ... 90%     37 of     41 study items found in association
#  42%     41 of     97 study items found in population(20652)
# Calculating 1,754 uncorrected p-values using fisher_scipy_stats
#    1,754 GO terms are associated with 19,433 of 20,652 population items
#       50 GO terms are associated with     37 of     97 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 97 IDs ... 83%     34 of     41 study items found in association
#  42%     41 of     97 study items found in population(20652)
# Calculating 4,419 uncorrected p-values using fisher_scipy_stats
#    4,419 GO terms are associated with 18,194 of 20,652 population items
#       70 GO terms are associated with     34 of     97 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#       0 items. NOT WRITING module18_go_enrichment.tsv
#
# Run BP Gene Ontology Analysis: current study set of 115 IDs ... 88%     92 of    104 study items found in association
#  90%    104 of    115 study items found in population(20652)
# Calculating 12,417 uncorrected p-values using fisher_scipy_stats
#   12,417 GO terms are associated with 18,501 of 20,652 population items
#      474 GO terms are associated with     92 of    115 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run CC Gene Ontology Analysis: current study set of 115 IDs ... 95%     99 of    104 study items found in association
#  90%    104 of    115 study items found in population(20652)
# Calculating 1,754 uncorrected p-values using fisher_scipy_stats
#    1,754 GO terms are associated with 19,433 of 20,652 population items
#      133 GO terms are associated with     99 of    115 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#       12 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Run MF Gene Ontology Analysis: current study set of 115 IDs ... 91%     95 of    104 study items found in association
#  90%    104 of    115 study items found in population(20652)
# Calculating 4,419 uncorrected p-values using fisher_scipy_stats
#    4,419 GO terms are associated with 18,194 of 20,652 population items
#      200 GO terms are associated with     95 of    115 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#       1 items WROTE: module19_go_enrichment.tsv

# %%
pwd
# Out:
# '/ceph/projects/v4_phase3_paper/analysis/gnvae/disvae/model/embedding/leiden/_m'
